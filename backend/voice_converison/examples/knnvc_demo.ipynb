# %% [markdown]
# # KNN VC DEMO
# 남자 성우를 source로 하고 여자 성우 목소리를 ref로 줘서 source 음성을 여자 성우 목소리로 발화하는 실습.
# - source 발화의 텍스트는 'SPK064KBSCU001M001.wav' 의 텍스트로 함.
#   - **지난해 극장을 찾은 연간 관객 수가 역대 최다치를 기록했습니다.**
# - colab에서 실행 시 runtime type을 GPU(T4)로 변경해야 함.
# - 파일은 직접 올리시길.. drop down

# %%
import torch, torchaudio

knn_vc = torch.hub.load('bshall/knn-vc', 'knn_vc', prematched=True, trust_repo=True, pretrained=True, device='cuda')
# Out:
# Using cache found in /root/.cache/torch/hub/bshall_knn-vc_master
# Removing weight norm...
# [HiFiGAN] Generator loaded with 16,523,393 parameters.
# WavLM-Large loaded with 315,453,120 parameters.

# %% [markdown]
# ## 음성 파일의 주파수는 자동으로 resample 됨
#  - 44100 -> 16000

# %%
# path to 16kHz, single-channel, source waveform
src_wav_path = '/content/SPK064KBSCU001M001.wav'
# list of paths to all reference waveforms (each must be 16kHz, single-channel) from the target speaker
ref_wav_paths = ['/content/SPK014KBSCU001F001.wav', "/content/SPK014KBSCU001F002.wav",
                 '/content/SPK014KBSCU001F003.wav', "/content/SPK014KBSCU001F004.wav",
                 '/content/SPK014KBSCU001F005.wav', "/content/SPK014KBSCU001F006.wav",
                 '/content/SPK014KBSCU001F007.wav',]

query_seq = knn_vc.get_features(src_wav_path)
matching_set = knn_vc.get_matching_set(ref_wav_paths)
# Out:
# resample 44100 to 16000 in /content/SPK064KBSCU001M001.wav
# resample 44100 to 16000 in /content/SPK014KBSCU001F001.wav
# resample 44100 to 16000 in /content/SPK014KBSCU001F002.wav
# resample 44100 to 16000 in /content/SPK014KBSCU001F003.wav
# resample 44100 to 16000 in /content/SPK014KBSCU001F004.wav
# resample 44100 to 16000 in /content/SPK014KBSCU001F005.wav
# resample 44100 to 16000 in /content/SPK014KBSCU001F006.wav
# resample 44100 to 16000 in /content/SPK014KBSCU001F007.wav

# %%
out_wav = knn_vc.match(query_seq, matching_set, topk=4)

# %%
import IPython.display as ipd

# %% [markdown]
# ## 결과 값

# %%
ipd.Audio(out_wav.numpy(), rate=16000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
